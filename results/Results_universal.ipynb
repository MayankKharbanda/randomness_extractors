# %%
import matplotlib.pyplot as plt

# %%
location_result = 'results/universal'
no_files = 3

# %%
small_crush = [0]*11
for fl in range(1,no_files+1):
    for te in range(1,11):
        with open(f'{location_result}/small_crush_result/file_{fl}/small_crush/{te}.txt','r') as fr:
            lines = fr.readlines()
            temp=1
            while(True):
                if(lines[-temp].strip() == ''):
                    temp+=1
                    continue
                elif 'passed' in lines[-temp]:
                    small_crush[te] = small_crush[te] +1
                break

# %%
crush = [0]*97
for fl in range(1,no_files):
    for te in range(1,97):
        with open(f'{location_result}/crush_result/file_{fl}/crush/{te}.txt','r') as fr:
            lines = fr.readlines()
            temp=1
            while(True):
                if(lines[-temp].strip() == ''):
                    temp+=1
                    continue
                elif 'passed' in lines[-temp]:
                    crush[te] = crush[te] +1
                break
                
for te in range(1,97):
    with open(f'{location_result}/crush_result_2/file_1/crush/{te}.txt','r') as fr:
        lines = fr.readlines()
        temp=1
        while(True):
            if(lines[-temp].strip() == ''):
                temp+=1
                continue
            elif 'passed' in lines[-temp]:
                crush[te] = crush[te] +1
            break

# %%
rabbit = [0]*27
for fl in range(1,no_files+1):
    for te in range(1,27):
        with open(f'{location_result}/rabbit_result/file_{fl}/rabbit/{te}.txt','r') as fr:
            lines = fr.readlines()
            temp=1
            while(True):
                if(lines[-temp].strip() == ''):
                    temp+=1
                    continue
                elif 'passed' in lines[-temp]:
                    rabbit[te] = rabbit[te] +1
                break

# %%
alphabit = [0]*10
for fl in range(1,no_files+1):
    for te in range(1,10):
        with open(f'{location_result}/alphabit_result/file_{fl}/alphabit/{te}.txt','r') as fr:
            lines = fr.readlines()
            temp=1
            while(True):
                if(lines[-temp].strip() == ''):
                    temp+=1
                    continue
                elif 'passed' in lines[-temp]:
                    alphabit[te] = alphabit[te] +1
                break

# %%
nist = [0]*16
FLAG = 0
for i in range(1, no_files):
    for j in range(1,16):
        with open(f'{location_result}/nist_result_univ/file_{i}/nist/{j}/finalAnalysisReport.txt','r') as fr:
            lines = fr.readlines()
            FLAG=0
            for line in lines[7:]:
                if (line.strip()==''):
                    break
                data=line.split()
                if(data[-2].find('/')==-1):
                    p_val=(int(data[-3].split('/')[0]))    
                else:
                    p_val=(int(data[-2].split('/')[0]))
                if(j==12 or j==13): 
                    if(p_val<85):
                        FLAG=1
                        break
                else:
                    if(p_val<96):
                        FLAG=1
                        break
            if(FLAG==0):
                nist[j]+=1
                
for j in range(1,16):
    with open(f'{location_result}/nist_result_uni_2/file_1/nist/{j}/finalAnalysisReport.txt','r') as fr:
        lines = fr.readlines()
        FLAG=0
        for line in lines[7:]:
            if (line.strip()==''):
                break
            data=line.split()
            if(data[-2].find('/')==-1):
                p_val=(int(data[-3].split('/')[0]))    
            else:
                p_val=(int(data[-2].split('/')[0]))
            if(j==12 or j==13): 
                if(p_val<85):
                    FLAG=1
                    break
            else:
                if(p_val<96):
                    FLAG=1
                    break
        if(FLAG==0):
            nist[j]+=1

# %%
dieharder = []
for i in range(15):
    dieharder.append([0,0,0])
dieharder_dict = {'PASSED':0,'FAILED':1, 'WEAK':2}
for i in range(1,no_files+1):
    for test in range(15):
        with open(f'{location_result}/dieharder_result/file_{i}/dieharder/{test}.txt','r') as fr:
            lines = fr.readlines()
            dieharder[test][dieharder_dict[(lines[-1].split('|')[-1]).strip()]] = dieharder[test][dieharder_dict[(lines[-1].split('|')[-1]).strip()]] +1

# %%
dieharder_2 = []
dieharder_2 = [[[0,0,0] for tupl in range(2)] for test in range(3)]
for i in range(1,no_files+1):
    for test in range(15,18):
        with open(f'{location_result}/dieharder_result/file_{i}/dieharder/{test}.txt','r') as fr:
            lines = fr.readlines()
            dieharder_2[test-15][0][dieharder_dict[(lines[-2].split('|')[-1]).strip()]] = dieharder_2[test-15][0][dieharder_dict[(lines[-2].split('|')[-1]).strip()]] +1
            dieharder_2[test-15][1][dieharder_dict[(lines[-1].split('|')[-1]).strip()]] = dieharder_2[test-15][1][dieharder_dict[(lines[-1].split('|')[-1]).strip()]] +1

# %%
sts = []
for i in range(2):
    sts.append([0,0,0])
for i in range(1,no_files+1):
    for test in range(100,102):
        with open(f'{location_result}/dieharder_result/file_{i}/dieharder/{test}.txt','r') as fr:
            lines = fr.readlines()
            sts[test-100][dieharder_dict[(lines[-1].split('|')[-1]).strip()]] = sts[test-100][dieharder_dict[(lines[-1].split('|')[-1]).strip()]] +1

# %%
sts_2 = []
for i in range(30):
    sts_2.append([0,0,0])
for i in range(1,no_files+1):
    test = 102
    with open(f'{location_result}/dieharder_result/file_{i}/dieharder/{test}.txt','r') as fr:
        t_no = 0
        for line in fr.readlines():
            if('sts_serial' in line):
                sts_2[t_no][dieharder_dict[(line.split('|')[-1]).strip()]] = sts_2[t_no][dieharder_dict[(line.split('|')[-1]).strip()]] +1
                t_no = t_no+1

# %%
rgb = []
rgb = [[0,0,0] for tupl in range(1,13)]
for i in range(1,no_files+1):
    for tple in range(1,13):
        with open(f'{location_result}/dieharder_result/file_{i}/dieharder/200_{tple}.txt','r') as fr:
            lines = fr.readlines()
            rgb[tple-1][dieharder_dict[(lines[-1].split('|')[-1]).strip()]] = rgb[tple-1][dieharder_dict[(lines[-1].split('|')[-1]).strip()]] +1

# %%
rgb_1 = []
rgb_1 = [[0,0,0] for tupl in range(2,6)]
for i in range(1,no_files+1):
    for tple in range(2,6):
        with open(f'{location_result}/dieharder_result/file_{i}/dieharder/201_{tple}.txt','r') as fr:
            lines = fr.readlines()
            rgb_1[tple-2][dieharder_dict[(lines[-1].split('|')[-1]).strip()]] = rgb_1[tple-2][dieharder_dict[(lines[-1].split('|')[-1]).strip()]] +1

# %%
rgb_2 = []
rgb_2 = [[0,0,0] for tupl in range(2,6)]
for i in range(1,no_files+1):
    for tple in range(2,6):
        with open(f'{location_result}/dieharder_result/file_{i}/dieharder/202_{tple}.txt','r') as fr:
            lines = fr.readlines()
            rgb_2[tple-2][dieharder_dict[(lines[-1].split('|')[-1]).strip()]] = rgb_2[tple-2][dieharder_dict[(lines[-1].split('|')[-1]).strip()]] +1

# %%
rgb_3 = []
rgb_3 = [[0,0,0] for tupl in range(33)]
for i in range(1, no_files+1):
    for tple in range(33):
        with open(f'{location_result}/dieharder_result/file_{i}/dieharder/203_{tple}.txt','r') as fr:
            lines = fr.readlines()
            rgb_3[tple][dieharder_dict[(lines[-1].split('|')[-1]).strip()]] = rgb_3[tple][dieharder_dict[(lines[-1].split('|')[-1]).strip()]] +1

# %%
rgb_4 = []
for i in range(204, 210):
    rgb_4.append([0,0,0])
for i in range(1,no_files+1):
    for test in range(204, 210):
        with open(f'{location_result}/dieharder_result/file_{i}/dieharder/{test}.txt','r') as fr:
            lines = fr.readlines()
            rgb_4[test-204][dieharder_dict[(lines[-1].split('|')[-1]).strip()]] = rgb_4[test-204][dieharder_dict[(lines[-1].split('|')[-1]).strip()]] +1

# %%
fig,a =  plt.subplots(figsize=(12,8))
fig.tight_layout(pad=0.5)
fig.text(0.5, 0.0, 'Test_number', ha='center')
fig.text(-0.02, 0.5, 'Tests_iteration', va='center', rotation='vertical')



###################subplot-1#################################
plt.subplot(2,2,1)
plt.bar(range(1,11),small_crush[1:])
plt.title('small_crush')



###################subplot-2#################################
plt.subplot(2,2,2)
plt.bar(range(1,27),rabbit[1:])
plt.title('rabbit')



###################subplot-3#################################
plt.subplot(2,2,3)
plt.bar(range(1,10),alphabit[1:])
plt.title('alphabit')



###################subplot-4#################################
plt.subplot(2,2,4)
plt.bar(range(1,16),nist[1:])
plt.title('nist')


plt.show()
fig.savefig('fig/4_suites.png', bbox_inches='tight')

# %%
fig = plt.figure(figsize = (12,3))
ax = fig.add_axes([0,0,1,1])
ax.bar(range(1,97),crush[1:])
plt.title('crush')
plt.ylabel('Tests_passed')
plt.xlabel('Test_number')
plt.show()
fig.savefig('fig/crush.png', bbox_inches='tight')

# %%
fig,ax =  plt.subplots(figsize=(12,15), sharey=True)
fig.tight_layout(pad=0.3)
fig.text(0.5, 0.0, 'Test_number/tuple', ha='center')
fig.text(-0.02, 0.5, 'Tests_iteration', va='center', rotation='vertical')



###################subplot-1#################################
plt.subplot(5,2,1)
x = range(15)
y1 = [pas for pas,fail,weak in dieharder]
y2 = [weak for pas,fail,weak in dieharder]
y3 = [fail for pas,fail,weak in dieharder]
plt.bar(x, y1, color = 'g')
plt.bar(x, y2, bottom = y1, color = 'orange')
plt.bar(x, y3, bottom = [sum(x) for x in zip(y1, y2)], color = 'r')
plt.title('dieharder')






###################subplot-2#################################
plt.subplot(5,2,2)
x = [f'{test}_{tupl}' for test in range(15,18) for tupl in range(1,3)]
y1 = [pas for i in range(3) for pas, fail, weak in dieharder_2[i]]
y2 = [weak for i in range(3) for pas, fail, weak in dieharder_2[i]]
y3 = [fail for i in range(3) for pas, fail, weak in dieharder_2[i]]
plt.bar(x, y1, color = 'g')
plt.bar(x, y2, bottom = y1, color = 'orange')
plt.bar(x, y3, bottom = [sum(x) for x in zip(y1, y2)], color = 'r')
plt.title('dieharder')







###################subplot-3#################################
plt.subplot(5,2,3)
x = ['100','101']
y1 = [pas for pas,fail,weak in sts]
y2 = [weak for pas,fail,weak in sts]
y3 = [fail for pas,fail,weak in sts]
plt.bar(x, y1, color = 'g')
plt.bar(x, y2, bottom = y1, color = 'orange')
plt.bar(x, y3, bottom = [sum(x) for x in zip(y1, y2)], color = 'r')
plt.title('sts')





###################subplot-4#################################
plt.subplot(5,2,4)
x = range(30)
y1 = [pas for pas,fail,weak in sts_2]
y2 = [weak for pas,fail,weak in sts_2]
y3 = [fail for pas,fail,weak in sts_2]
plt.bar(x, y1, color = 'g')
plt.bar(x, y2, bottom = y1, color = 'orange')
plt.bar(x, y3, bottom = [sum(x) for x in zip(y1, y2)], color = 'r')
plt.title('sts_102')





###################subplot-5#################################
plt.subplot(5,2,5)
x = range(1,13)
y1 = [pas for pas,fail,weak in rgb]
y2 = [weak for pas,fail,weak in rgb]
y3 = [fail for pas,fail,weak in rgb]
plt.bar(x, y1, color = 'g')
plt.bar(x, y2, bottom = y1, color = 'orange')
plt.bar(x, y3, bottom = [sum(x) for x in zip(y1, y2)], color = 'r')
plt.title('rgb_200')



###################subplot-6#################################
plt.subplot(5,2,6)
x = range(2,6)
y1 = [pas for pas,fail,weak in rgb_1]
y2 = [weak for pas,fail,weak in rgb_1]
y3 = [fail for pas,fail,weak in rgb_1]
plt.bar(x, y1, color = 'g')
plt.bar(x, y2, bottom = y1, color = 'orange')
plt.bar(x, y3, bottom = [sum(x) for x in zip(y1, y2)], color = 'r')
plt.title('rgb_201')





###################subplot-7#################################
plt.subplot(5,2,7)
x = range(2,6)
y1 = [pas for pas,fail,weak in rgb_2]
y2 = [weak for pas,fail,weak in rgb_2]
y3 = [fail for pas,fail,weak in rgb_2]
plt.bar(x, y1, color = 'g')
plt.bar(x, y2, bottom = y1, color = 'orange')
plt.bar(x, y3, bottom = [sum(x) for x in zip(y1, y2)], color = 'r')
plt.title('rgb_202')




###################subplot-8#################################
plt.subplot(5,2,8)
x = range(33)
y1 = [pas for pas,fail,weak in rgb_3]
y2 = [weak for pas,fail,weak in rgb_3]
y3 = [fail for pas,fail,weak in rgb_3]
plt.bar(x, y1, color = 'g')
plt.bar(x, y2, bottom = y1, color = 'orange')
plt.bar(x, y3, bottom = [sum(x) for x in zip(y1, y2)], color = 'r')
plt.title('rgb_203')




###################subplot-9#################################
plt.subplot(5,2,9)
x = range(204, 210)
y1 = [pas for pas,fail,weak in rgb_4]
y2 = [weak for pas,fail,weak in rgb_4]
y3 = [fail for pas,fail,weak in rgb_4]
plt.bar(x, y1, color = 'g')
plt.bar(x, y2, bottom = y1, color = 'orange')
plt.bar(x, y3, bottom = [sum(x) for x in zip(y1, y2)], color = 'r')
plt.title('rgb/dab')



fig.legend(['pass','weak','fail'])

plt.show()
fig.savefig('fig/dieharder.png', bbox_inches='tight')

# %%
ent_test = {
    #'File_bytes' : 0,
    'Entropy' : 1,
    'Chi-square' : 2,
    'Mean' : 3,
    'Monte-Carlo' : 4,
    'Corr' : 5
    }
ent_stat = {
    'Count' : 0,
    'Fract' : 1
    }

# %%
result_arr = [None]*no_files
result_stat_arr = []
for i in range(no_files):
    result_stat_arr.append([None]*256)
for i in range(no_files):
    with open(f'{location_result}/ent_result/{i}.txt','r') as fr:
        lines = fr.readlines()
        result_arr[i] = [float(x.strip()) for x in lines[1].split(',')[1:]]
        number = 0
        for line in lines[3:]:
            result_stat_arr[i][number] = [float(x.strip()) for x in line.split(',')[2:]]
            number = number+1

# %%
fig,ax =  plt.subplots(figsize=(12,15), sharex=True)
fig.tight_layout(pad=0.3)
fig.text(0.5, 0.0, 'Tests_iteration', ha='center')
fig.text(-0.05, 0.5, 'Value', va='center', rotation='vertical')

v_line = [None, 8, 256, 127.5, 3.14159, 0]


for test,value in ent_test.items():
    
    plt.subplot(3,2,value)
    plt.scatter(range(1, no_files+1),[result[value] for result in result_arr])
    plt.plot([1,no_files+1], [v_line[value], v_line[value]], color = 'g')
    plt.title(test)
    

plt.show()
fig.savefig('fig/ent.png', bbox_inches='tight')

# %%
bias_arr_glo = []
fig,ax =  plt.subplots(figsize=(12,8), sharex=True, sharey=True)
fig.tight_layout(pad=0.3)
fig.text(0.5, 0.0, 'Value', ha='center')
fig.text(-0.05, 0.5, 'Bias', va='center', rotation='vertical')
    
for i in range(len(result_arr)):
    
    bias_arr = [ ((1/256)-(file_stat[ent_stat['Count']]/result_arr[i][0])) for file_stat in result_stat_arr[i]]
    bias_arr_glo.append(bias_arr)
    plt.subplot(2,2,i+1)
    plt.plot(range(256), bias_arr)
    plt.plot([0,255], [0,0], color='k')

plt.show()
fig.savefig('fig/bias.png', bbox_inches='tight')
